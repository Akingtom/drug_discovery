# %% [markdown]
# <a href="https://colab.research.google.com/github/Akingtom/drug_discovery/blob/main/Drug%20discovery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.read_csv('/content/Epidermal growth factor receptor_02_bioactivity_data_preprocessed.csv')
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 2          CHEMBL137635        CN(c1ccccc1)c1ncnc2ccc(N/N=N/Cc3ccccn3)cc12
# 3          CHEMBL306988             CC(=C(C#N)C#N)c1ccc(NC(=O)CCC(=O)O)cc1
# 4           CHEMBL66879                             O=C(O)/C=C/c1ccc(O)cc1
# ...                 ...                                                ...
# 9789      CHEMBL5270334  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4ccn(C)c4c3)n2...
# 9790      CHEMBL5271151  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 9791      CHEMBL5265870  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 9792      CHEMBL5269747  C=CC(=O)Nc1cc(Nc2ncc(Br)c(Nc3ccc4c(c3)CCC4)n2)...
# 9793      CHEMBL5286080  C=CC(=O)Nc1cc(Nc2nccc(Nc3ccc4c(ccn4C)c3)n2)c(O...
#
#       standard_value
# 0               41.0
# 1              170.0
# ...

# %%
df5.to_csv('Epidermal growth factor receptor_03_bioactivity_data_curated.csv', index=False)

# %%
! zip Epidermalgrowthfactorreceptor.zip *.csv
# Out:
#   adding: Epidermal growth factor receptor_01_bioactivity_data_raw.csv (deflated 93%)
#   adding: Epidermal growth factor receptor_02_bioactivity_data_preprocessed.csv (deflated 82%)
#   adding: Epidermal growth factor receptor_03_bioactivity_data_curated.csv (deflated 83%)

# %%
! ls -l
# Out:
# total 14108
# drwx------ 5 root root     4096 May 28 18:23  drive
# -rw-r--r-- 1 root root 10717111 May 28 17:27 'Epidermal growth factor receptor_01_bioactivity_data_raw.csv'
# -rw-r--r-- 1 root root   739063 May 28 17:33 'Epidermal growth factor receptor_02_bioactivity_data_preprocessed.csv'
# -rw-r--r-- 1 root root   820480 May 28 18:40 'Epidermal growth factor receptor_03_bioactivity_data_curated.csv'
# -rw-r--r-- 1 root root  1076262 May 28 18:42  Epidermalgrowthfactorreceptor.zip
# -rw-r--r-- 1 root root  1076262 May 28 18:42  Epidermal.zip
# drwxr-xr-x 1 root root     4096 May 23 13:25  sample_data
